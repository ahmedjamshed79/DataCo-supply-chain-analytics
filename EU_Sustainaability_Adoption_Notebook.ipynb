# %% [markdown]
# ## <div style="border-radius:0px; border:#363636 solid; padding: 15px; background-color: #242F40; font-size:100%; text-align:left; color: #FFFFFF">Import Libraries</div>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Apply the theme
sns.set_theme()
sns.set_style("whitegrid")

# %% [markdown]
# ## <div style="border-radius:0px; border:#363636 solid; padding: 15px; background-color: #242F40; font-size:100%; text-align:left; color: #FFFFFF">Import Dataset</div>

# %%
df = pd.read_csv("dataset/global-data-on-sustainable-energy.csv", delimiter=",")

# %%
df.head()
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
# 3  Afghanistan  2003                                14.738506
# 4  Afghanistan  2004                                20.064968
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
# 3                                9.5
# 4                               10.9
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# 4                                               7.75
#
#    Financial flows to developing countries (US $)  \
# 0                                         20000.0
# 1                                        130000.0
# 2                                       3950000.0
# 3                                      25970000.0
# 4                                             NaN
#
#    Renewable energy share in the total final energy consumption (%)  \
# 0                                              44.99
# 1                                              45.60
# 2                                              37.83
# 3                                              36.66
# 4                                              44.24
#
#    Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 0                                 0.16                             0.0
# 1                                 0.09                             0.0
# 2                                 0.13                             0.0
# 3                                 0.31                             0.0
# 4                                 0.33                             0.0
#
#    Electricity from renewables (TWh)  ...  \
# 0                               0.31  ...
# 1                               0.50  ...
# 2                               0.56  ...
# 3                               0.63  ...
# 4                               0.56  ...
#
#    Primary energy consumption per capita (kWh/person)  \
# 0                                          302.59482
# 1                                          236.89185
# 2                                          210.86215
# 3                                          229.96822
# 4                                          204.23125
#
#    Energy intensity level of primary energy (MJ/$2017 PPP GDP)  \
# 0                                               1.64
# 1                                               1.74
# 2                                               1.40
# 3                                               1.40
# 4                                               1.20
#
#    Value_co2_emissions_kt_by_country  \
# 0                         760.000000
# 1                         730.000000
# 2                        1029.999971
# 3                        1220.000029
# 4                        1029.999971
#
#    Renewables (% equivalent primary energy)  gdp_growth  gdp_per_capita  \
# 0                                       NaN         NaN             NaN
# 1                                       NaN         NaN             NaN
# 2                                       NaN         NaN      179.426579
# 3                                       NaN    8.832278      190.683814
# 4                                       NaN    1.414118      211.382074
#
#    Density\n(P/Km2) Land Area(Km2)  Latitude  Longitude
# 0                60       652230.0  33.93911  67.709953
# 1                60       652230.0  33.93911  67.709953
# 2                60       652230.0  33.93911  67.709953
# 3                60       652230.0  33.93911  67.709953
# 4                60       652230.0  33.93911  67.709953
#
# [5 rows x 21 columns]

# %% [markdown]
# ## <div style="border-radius:0px; border:#363636 solid; padding: 15px; background-color: #242F40; font-size:100%; text-align:left; color: #FFFFFF">Dataset Info</div>

# %%
df.shape
# Out:
# (3649, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3649 entries, 0 to 3648
# Data columns (total 21 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Entity                                                            3649 non-null   object
#  1   Year                                                              3649 non-null   int64
#  2   Access to electricity (% of population)                           3639 non-null   float64
#  3   Access to clean fuels for cooking                                 3480 non-null   float64
#  4   Renewable-electricity-generating-capacity-per-capita              2718 non-null   float64
#  5   Financial flows to developing countries (US $)                    1560 non-null   float64
#  6   Renewable energy share in the total final energy consumption (%)  3455 non-null   float64
#  7   Electricity from fossil fuels (TWh)                               3628 non-null   float64
#  8   Electricity from nuclear (TWh)                                    3523 non-null   float64
#  9   Electricity from renewables (TWh)                                 3628 non-null   float64
#  10  Low-carbon electricity (% electricity)                            3607 non-null   float64
#  11  Primary energy consumption per capita (kWh/person)                3649 non-null   float64
#  12  Energy intensity level of primary energy (MJ/$2017 PPP GDP)       3442 non-null   float64
#  13  Value_co2_emissions_kt_by_country                                 3221 non-null   float64
#  14  Renewables (% equivalent primary energy)                          1512 non-null   float64
#  15  gdp_growth                                                        3332 non-null   float64
#  16  gdp_per_capita                                                    3367 non-null   float64
#  17  Density\n(P/Km2)                                                  3648 non-null   object
#  18  Land Area(Km2)                                                    3648 non-null   float64
#  19  Latitude                                                          3648 non-null   float64
#  20  Longitude                                                         3648 non-null   float64
# dtypes: float64(18), int64(1), object(2)
# memory usage: 598.8+ KB

# %%
df.describe()
# Out:
#               Year  Access to electricity (% of population)  \
# count  3649.000000                              3639.000000
# mean   2010.038367                                78.933702
# std       6.054228                                30.275541
# min    2000.000000                                 1.252269
# 25%    2005.000000                                59.800890
# 50%    2010.000000                                98.361570
# 75%    2015.000000                               100.000000
# max    2020.000000                               100.000000
#
#        Access to clean fuels for cooking  \
# count                        3480.000000
# mean                           63.255287
# std                            39.043658
# min                             0.000000
# 25%                            23.175000
# 50%                            83.150000
# 75%                           100.000000
# max                           100.000000
#
#        Renewable-electricity-generating-capacity-per-capita  \
# count                                        2718.000000
# mean                                          113.137498
# std                                           244.167256
# min                                             0.000000
# 25%                                             3.540000
# 50%                                            32.910000
# 75%                                           112.210000
# max                                          3060.190000
#
#        Financial flows to developing countries (US $)  \
# count                                    1.560000e+03
# mean                                     9.422400e+07
# std                                      2.981544e+08
# min                                      0.000000e+00
# 25%                                      2.600000e+05
# 50%                                      5.665000e+06
# 75%                                      5.534750e+07
# max                                      5.202310e+09
#
#        Renewable energy share in the total final energy consumption (%)  \
# count                                        3455.000000
# mean                                           32.638165
# std                                            29.894901
# min                                             0.000000
# 25%                                             6.515000
# 50%                                            23.300000
# 75%                                            55.245000
# max                                            96.040000
#
#        Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# count                          3628.000000                     3523.000000
# mean                             70.365003                       13.450190
# std                             348.051866                       73.006623
# min                               0.000000                        0.000000
# 25%                               0.290000                        0.000000
# 50%                               2.970000                        0.000000
# 75%                              26.837500                        0.000000
# max                            5184.130000                      809.410000
#
#        Electricity from renewables (TWh)  \
# count                        3628.000000
# mean                           23.968010
# std                           104.431085
# min                             0.000000
# 25%                             0.040000
# 50%                             1.470000
# 75%                             9.600000
# max                          2184.940000
#
#        Low-carbon electricity (% electricity)  \
# count                             3607.000000
# mean                                36.801182
# std                                 34.314884
# min                                  0.000000
# 25%                                  2.877847
# 50%                                 27.865068
# 75%                                 64.403792
# max                                100.000010
#
#        Primary energy consumption per capita (kWh/person)  \
# count                                        3649.000000
# mean                                        25743.981745
# std                                         34773.221366
# min                                             0.000000
# 25%                                          3116.737300
# 50%                                         13120.570000
# 75%                                         33892.780000
# max                                        262585.700000
#
#        Energy intensity level of primary energy (MJ/$2017 PPP GDP)  \
# count                                        3442.000000
# mean                                            5.307345
# std                                             3.532020
# min                                             0.110000
# 25%                                             3.170000
# 50%                                             4.300000
# 75%                                             6.027500
# max                                            32.570000
#
#        Value_co2_emissions_kt_by_country  \
# count                       3.221000e+03
# mean                        1.598665e+05
# std                         7.736611e+05
# min                         1.000000e+01
# 25%                         2.020000e+03
# 50%                         1.050000e+04
# 75%                         6.058000e+04
# max                         1.070722e+07
#
#        Renewables (% equivalent primary energy)   gdp_growth  gdp_per_capita  \
# count                               1512.000000  3332.000000     3367.000000
# mean                                  11.986707     3.441610    13283.774348
# std                                   14.994644     5.686720    19709.866716
# min                                    0.000000   -62.075920      111.927225
# 25%                                    2.137095     1.383302     1337.813437
# 50%                                    6.290766     3.559855     4578.633208
# 75%                                   16.841638     5.830099    15768.615365
# max                                   86.836586   123.139555   123514.196700
#
#        Land Area(Km2)     Latitude    Longitude
# count    3.648000e+03  3648.000000  3648.000000
# mean     6.332135e+05    18.246388    14.822695
# std      1.585519e+06    24.159232    66.348148
# min      2.100000e+01   -40.900557  -175.198242
# 25%      2.571300e+04     3.202778   -11.779889
# 50%      1.176000e+05    17.189877    19.145136
# 75%      5.131200e+05    38.969719    46.199616
# max      9.984670e+06    64.963051   178.065032

# %% [markdown]
# ## <div style="border-radius:0px; border:#363636 solid; padding: 15px; background-color: #242F40; font-size:100%; text-align:left; color: #FFFFFF">Filter European Countries</div>

# %%
#List of all the European countries to filter out from the dataset
european_countries = [
    'Albania', 'Andorra', 'Armenia', 'Austria', 'Azerbaijan', 'Belarus',
    'Belgium', 'Bosnia and Herzegovina', 'Bulgaria', 'Croatia', 'Cyprus',
    'Czech Republic', 'Denmark', 'Estonia', 'Finland', 'France', 'Georgia',
    'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy', 'Kazakhstan',
    'Latvia', 'Liechtenstein', 'Lithuania', 'Luxembourg', 'Malta', 'Moldova',
    'Monaco', 'Montenegro', 'Netherlands', 'North Macedonia', 'Norway', 'Poland',
    'Portugal', 'Romania', 'Russia', 'San Marino', 'Serbia', 'Slovakia', 'Slovenia',
    'Spain', 'Sweden', 'Switzerland', 'Turkey', 'Ukraine', 'United Kingdom', 'Vatican City'
]

# %%
# Filter based on whether the 'country' column is in the european_countries list
eu_df = df[df['Entity'].isin(european_countries)]

# %%
#Changing column 'Entity' to 'Country' coz it makes more sense
eu_df.rename(columns={'Entity': 'Country'}, inplace=True)
# Out:
# /var/folders/j2/980rdpms4_3bg6wfk9t4lhtc0000gn/T/ipykernel_12723/3877528316.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eu_df.rename(columns={'Entity': 'Country'}, inplace=True)

# %%
eu_df.head()
# Out:
#     Country  Year  Access to electricity (% of population)  \
# 21  Albania  2000                                    100.0
# 22  Albania  2001                                    100.0
# 23  Albania  2002                                    100.0
# 24  Albania  2003                                    100.0
# 25  Albania  2004                                    100.0
#
#     Access to clean fuels for cooking  \
# 21                               38.2
# 22                               40.5
# 23                               43.2
# 24                               46.4
# 25                               49.0
#
#     Renewable-electricity-generating-capacity-per-capita  \
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
#
#     Renewable energy share in the total final energy consumption (%)  \
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
#
#     Electricity from fossil fuels (TWh)  Electricity from nuclear (TWh)  \
# 21                                 0.14                             0.0
# 22                                 0.13                             0.0
# 23                                 0.16                             0.0
# 24                                 0.10                             0.0
# 25                                 0.13                             0.0
#
#     Electricity from renewables (TWh)  Low-carbon electricity (% electricity)  \
# 21                               4.55                               97.014930
# 22                               3.52                               96.438354
# 23                               3.48                               95.604390
# 24                               5.12                               98.084300
# 25                               5.41                               97.653430
#
#     Primary energy consumption per capita (kWh/person)  \
# 21                                          9029.4375
# 22                                          8635.5320
# 23                                          9443.5550
# 24                                         10756.6120
# 25                                         11586.9510
#
#     Energy intensity level of primary energy (MJ/$2017 PPP GDP)  \
# 21                                               4.13
# 22                                               3.89
# 23                                               4.10
# 24                                               3.80
# 25                                               3.96
#
#     Value_co2_emissions_kt_by_country  \
# 21                        3170.000000
# 22                        3230.000000
# 23                        3759.999990
# 24                        4070.000172
# 25                        4250.000000
#
#     Renewables (% equivalent primary energy)  gdp_growth  gdp_per_capita  \
# 21                                       NaN    6.946217     1126.683340
# 22                                       NaN    8.293313     1281.659826
# 23                                       NaN    4.536524     1425.124219
# 24                                       NaN    5.528637     1846.120121
# 25                                       NaN    5.514668     2373.581292
#
#    Density\n(P/Km2)  Land Area(Km2)   Latitude  Longitude
# 21              105         28748.0  41.153332  20.168331
# 22              105         28748.0  41.153332  20.168331
# 23              105         28748.0  41.153332  20.168331
# 24              105         28748.0  41.153332  20.168331
# 25              105         28748.0  41.153332  20.168331

# %%
#Saving filtered dataset with EU countries for future use
#eu_df.to_csv("./dataset/eu-data-on-sustainable-energy.csv", index=False)

# %% [markdown]
# ## <div style="border-radius:0px; border:#363636 solid; padding: 15px; background-color: #242F40; font-size:100%; text-align:left; color: #FFFFFF">Filtered Dataset Info</div>

# %%
eu_df.shape
# Out:
# (868, 21)

# %%
eu_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 868 entries, 21 to 3501
# Data columns (total 21 columns):
#  #   Column                                                            Non-Null Count  Dtype
# ---  ------                                                            --------------  -----
#  0   Country                                                           868 non-null    object
#  1   Year                                                              868 non-null    int64
#  2   Access to electricity (% of population)                           868 non-null    float64
#  3   Access to clean fuels for cooking                                 847 non-null    float64
#  4   Renewable-electricity-generating-capacity-per-capita              105 non-null    float64
#  5   Financial flows to developing countries (US $)                    76 non-null     float64
#  6   Renewable energy share in the total final energy consumption (%)  806 non-null    float64
#  7   Electricity from fossil fuels (TWh)                               868 non-null    float64
#  8   Electricity from nuclear (TWh)                                    847 non-null    float64
#  9   Electricity from renewables (TWh)                                 868 non-null    float64
#  10  Low-carbon electricity (% electricity)                            868 non-null    float64
#  11  Primary energy consumption per capita (kWh/person)                868 non-null    float64
#  12  Energy intensity level of primary energy (MJ/$2017 PPP GDP)       826 non-null    float64
#  13  Value_co2_emissions_kt_by_country                                 786 non-null    float64
#  14  Renewables (% equivalent primary energy)                          735 non-null    float64
#  15  gdp_growth                                                        847 non-null    float64
#  16  gdp_per_capita                                                    847 non-null    float64
#  17  Density\n(P/Km2)                                                  868 non-null    object
#  18  Land Area(Km2)                                                    868 non-null    float64
#  19  Latitude                                                          868 non-null    float64
#  20  Longitude                                                         868 non-null    float64
# dtypes: float64(18), int64(1), object(2)
# memory usage: 181.5+ KB

# %% [markdown]
# ## <div style="border-radius:0px; border:#363636 solid; padding: 15px; background-color: #242F40; font-size:100%; text-align:left; color: #FFFFFF">Data Cleaning</div>

# %% [markdown]
# ## Visualizing Null Values

# %%
eu_nullValues = eu_df.isnull().T #.T to transpose the dataframe to make columns appear on x axis when creating heatmap
eu_nullValues
# Out:
#                                                      21     22     23    \
# Country                                             False  False  False
# Year                                                False  False  False
# Access to electricity (% of population)             False  False  False
# Access to clean fuels for cooking                   False  False  False
# Renewable-electricity-generating-capacity-per-c...   True   True   True
# Financial flows to developing countries (US $)       True   True   True
# Renewable energy share in the total final energ...   True   True   True
# Electricity from fossil fuels (TWh)                 False  False  False
# Electricity from nuclear (TWh)                      False  False  False
# Electricity from renewables (TWh)                   False  False  False
# Low-carbon electricity (% electricity)              False  False  False
# Primary energy consumption per capita (kWh/person)  False  False  False
# Energy intensity level of primary energy (MJ/$2...  False  False  False
# Value_co2_emissions_kt_by_country                   False  False  False
# Renewables (% equivalent primary energy)             True   True   True
# gdp_growth                                          False  False  False
# gdp_per_capita                                      False  False  False
# Density\n(P/Km2)                                    False  False  False
# Land Area(Km2)                                      False  False  False
# Latitude                                            False  False  False
# Longitude                                           False  False  False
#
#                                                      24     25     26    \
# Country                                             False  False  False
# Year                                                False  False  False
# Access to electricity (% of population)             False  False  False
# Access to clean fuels for cooking                   False  False  False
# Renewable-electricity-generating-capacity-per-c...   True   True   True
# Financial flows to developing countries (US $)       True   True   True
# Renewable energy share in the total final energ...   True   True   True
# Electricity from fossil fuels (TWh)                 False  False  False
# Electricity from nuclear (TWh)                      False  False  False
# Electricity from renewables (TWh)                   False  False  False
# Low-carbon electricity (% electricity)              False  False  False
# Primary energy consumption per capita (kWh/person)  False  False  False
# Energy intensity level of primary energy (MJ/$2...  False  False  False
# Value_co2_emissions_kt_by_country                   False  False  False
# Renewables (% equivalent primary energy)             True   True   True
# gdp_growth                                          False  False  False
# gdp_per_capita                                      False  False  False
# Density\n(P/Km2)                                    False  False  False
# Land Area(Km2)                                      False  False  False
# Latitude                                            False  False  False
# Longitude                                           False  False  False
#
#                                                      27     28     29    \
# Country                                             False  False  False
# Year                                                False  False  False
# Access to electricity (% of population)             False  False  False
# Access to clean fuels for cooking                   False  False  False
# Renewable-electricity-generating-capacity-per-c...   True   True   True
# Financial flows to developing countries (US $)       True   True   True
# Renewable energy share in the total final energ...   True   True   True
# Electricity from fossil fuels (TWh)                 False  False  False
# Electricity from nuclear (TWh)                      False  False  False
# Electricity from renewables (TWh)                   False  False  False
# Low-carbon electricity (% electricity)              False  False  False
# Primary energy consumption per capita (kWh/person)  False  False  False
# Energy intensity level of primary energy (MJ/$2...  False  False  False
# Value_co2_emissions_kt_by_country                   False  False  False
# Renewables (% equivalent primary energy)             True   True   True
# gdp_growth                                          False  False  False
# gdp_per_capita                                      False  False  False
# Density\n(P/Km2)                                    False  False  False
# Land Area(Km2)                                      False  False  False
# Latitude                                            False  False  False
# Longitude                                           False  False  False
#
#                                                      30    ...   3492   3493  \
# Country                                             False  ...  False  False
# Year                                                False  ...  False  False
# Access to electricity (% of population)             False  ...  False  False
# Access to clean fuels for cooking                   False  ...  False  False
# Renewable-electricity-generating-capacity-per-c...   True  ...   True   True
# Financial flows to developing countries (US $)       True  ...   True   True
# Renewable energy share in the total final energ...   True  ...  False  False
# Electricity from fossil fuels (TWh)                 False  ...  False  False
# Electricity from nuclear (TWh)                      False  ...  False  False
# Electricity from renewables (TWh)                   False  ...  False  False
# Low-carbon electricity (% electricity)              False  ...  False  False
# Primary energy consumption per capita (kWh/person)  False  ...  False  False
# Energy intensity level of primary energy (MJ/$2...  False  ...  False  False
# Value_co2_emissions_kt_by_country                   False  ...  False  False
# Renewables (% equivalent primary energy)             True  ...  False  False
# gdp_growth                                          False  ...  False  False
# gdp_per_capita                                      False  ...  False  False
# Density\n(P/Km2)                                    False  ...  False  False
# Land Area(Km2)                                      False  ...  False  False
# Latitude                                            False  ...  False  False
# Longitude                                           False  ...  False  False
#
#                                                      3494   3495   3496  \
# Country                                             False  False  False
# Year                                                False  False  False
# Access to electricity (% of population)             False  False  False
# Access to clean fuels for cooking                   False  False  False
# Renewable-electricity-generating-capacity-per-c...   True   True   True
# Financial flows to developing countries (US $)       True   True   True
# Renewable energy share in the total final energ...  False  False  False
# Electricity from fossil fuels (TWh)                 False  False  False
# Electricity from nuclear (TWh)                      False  False  False
# Electricity from renewables (TWh)                   False  False  False
# Low-carbon electricity (% electricity)              False  False  False
# Primary energy consumption per capita (kWh/person)  False  False  False
# Energy intensity level of primary energy (MJ/$2...  False  False  False
# Value_co2_emissions_kt_by_country                   False  False  False
# Renewables (% equivalent primary energy)            False  False  False
# gdp_growth                                          False  False  False
# gdp_per_capita                                      False  False  False
# Density\n(P/Km2)                                    False  False  False
# Land Area(Km2)                                      False  False  False
# Latitude                                            False  False  False
# Longitude                                           False  False  False
#
#                                                      3497   3498   3499  \
# Country                                             False  False  False
# Year                                                False  False  False
# Access to electricity (% of population)             False  False  False
# Access to clean fuels for cooking                   False  False  False
# Renewable-electricity-generating-capacity-per-c...   True   True   True
# Financial flows to developing countries (US $)       True   True   True
# Renewable energy share in the total final energ...  False  False  False
# Electricity from fossil fuels (TWh)                 False  False  False
# Electricity from nuclear (TWh)                      False  False  False
# Electricity from renewables (TWh)                   False  False  False
# Low-carbon electricity (% electricity)              False  False  False
# Primary energy consumption per capita (kWh/person)  False  False  False
# Energy intensity level of primary energy (MJ/$2...  False  False  False
# Value_co2_emissions_kt_by_country                   False  False  False
# Renewables (% equivalent primary energy)            False  False  False
# gdp_growth                                          False  False  False
# gdp_per_capita                                      False  False  False
# Density\n(P/Km2)                                    False  False  False
# Land Area(Km2)                                      False  False  False
# Latitude                                            False  False  False
# Longitude                                           False  False  False
#
#                                                      3500   3501
# Country                                             False  False
# Year                                                False  False
# Access to electricity (% of population)             False  False
# Access to clean fuels for cooking                   False  False
# Renewable-electricity-generating-capacity-per-c...   True   True
# Financial flows to developing countries (US $)       True   True
# Renewable energy share in the total final energ...  False   True
# Electricity from fossil fuels (TWh)                 False  False
# Electricity from nuclear (TWh)                      False  False
# Electricity from renewables (TWh)                   False  False
# Low-carbon electricity (% electricity)              False  False
# Primary energy consumption per capita (kWh/person)  False  False
# Energy intensity level of primary energy (MJ/$2...  False   True
# Value_co2_emissions_kt_by_country                   False   True
# Renewables (% equivalent primary energy)            False  False
# gdp_growth                                          False  False
# gdp_per_capita                                      False  False
# Density\n(P/Km2)                                    False  False
# Land Area(Km2)                                      False  False
# Latitude                                            False  False
# Longitude                                           False  False
#
# [21 rows x 868 columns]

# %%
#Plotting a heat map to visualize the occurances of null values
# Here yellow cells represents null values
plt.figure(figsize=[13,6])
sns.heatmap(eu_nullValues, cbar=False, cmap='viridis', xticklabels=False)

plt.show()

# %% [markdown]
# ## Dropping Unnecessory columns

# %%
#List of countries which received financial aid
eu_countries_received_financial_flows = eu_df[eu_df["Financial flows to developing countries (US $)"].notnull()]["Country"].unique()
eu_countries_received_financial_flows
# Out:
# array(['Armenia', 'Azerbaijan', 'Georgia', 'Kazakhstan', 'Turkey'],
#       dtype=object)

# %%
#Dropping this column since it contains values for only 5 countries and it's not needed
eu_df.drop("Financial flows to developing countries (US $)", axis=1, inplace=True)
# Out:
# /var/folders/j2/980rdpms4_3bg6wfk9t4lhtc0000gn/T/ipykernel_12723/2510410007.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   eu_df.drop("Financial flows to developing countries (US $)", axis=1, inplace=True)

# %% [markdown]
# ## <div style="border-radius:0px; border:#363636 solid; padding: 15px; background-color: #242F40; font-size:100%; text-align:left; color: #FFFFFF">Renewable Energy Share Over Time</div>

# %%
#renewableShare = eu_df.loc[eu_df['Renewable energy share in the total final energy consumption (%)'].notnull(), ['Year', 'Renewable energy share in the total final energy consumption (%)']].sort_values('Year')

# %%
#Getting the columns required for Trend analysis
#grouping by 'Year' to get unique years and getting a mean of Renewable energy share... column to get a clean dataset
#for timeseries analysis and finally sorting by 'Year'
rnShare = eu_df[['Renewable energy share in the total final energy consumption (%)', 'Year']].groupby('Year').mean().sort_values('Year')

# %%
rnShare.head()
# Out:
#       Renewable energy share in the total final energy consumption (%)
# Year
# 2000                                          15.316667
# 2001                                          15.184872
# 2002                                          15.130000
# 2003                                          15.195897
# 2004                                          15.504359

# %%
#Since we grouped by 'Year', the 'Year' column has become and index. 
rnShare.index.dtype
# Out:
# dtype('int64')

# %%
# Plotting
plt.figure(figsize=[10,5])
sns.lineplot(
    data=rnShare,
    x=rnShare.index,
    y='Renewable energy share in the total final energy consumption (%)', 
    color="green",
    marker="o")

plt.title('Renewable Energy Share in Total Final Energy Consumption Over Time', fontdict={'fontsize':14})
plt.xlabel('Year', )
plt.ylabel('Renewable Energy Share (%)')
plt.xticks(rnShare.index[::2])
plt.show()
